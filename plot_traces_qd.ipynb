# %%
import os

# %%
os.listdir(r"Z:\Individual_Folders\Tobi\WF_axonimaging\axonal_imaging_tobi\data\raw")
# Out:
# ['JPCM-08699',
#  'JPCM-08704',
#  'JPCM-08780',
#  'JPCM-08781',
#  'JPCM-08782',
#  'JPCM-08842',
#  'JPCM-08843',
#  'JPCM-08844',
#  'README.md']

# %%
from wf_analysis.plot_traces import plot_traces_for_animal

cold_traces, warm_traces = plot_traces_for_animal(
    dataset_id="JPCM-08704",
    processed_root=r"Z:\Individual_Folders\Tobi\WF_axonimaging\axonal_imaging_tobi\data\processed",
    trace_basename_cold="roi_cold_trace",
    trace_basename_warm="roi_warm_trace",
)

# %%
from pathlib import Path
from wf_analysis.plot_traces import plot_traces_for_animal

processed_root = Path(r"Z:\Individual_Folders\Tobi\WF_axonimaging\axonal_imaging_tobi\data\processed")

for animal_dir in sorted(processed_root.iterdir()):
    if animal_dir.is_dir():
        dataset_id = animal_dir.name
        print(f"Plotting for {dataset_id}")
        plot_traces_for_animal(dataset_id=dataset_id, processed_root=processed_root)
# Out:
# Plotting for JPCM-08699
# Plotting for JPCM-08704
# Plotting for JPCM-08780
# Plotting for JPCM-08781
# Plotting for JPCM-08782
# Plotting for JPCM-08842
# Plotting for JPCM-08843
# Plotting for JPCM-08844

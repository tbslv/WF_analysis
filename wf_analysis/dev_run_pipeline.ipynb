# %%
from pathlib import Path
import copy
import yaml

from wf_analysis.pipeline import run_full_pipeline

# %%
def run_pipeline_for_dataset(
    config_path: str | Path,
    dataset_id: str,
    session_id: str,
    *,
    skip_motion: bool = True,
    skip_mask: bool = False,
    skip_dff: bool = False,
    skip_roi: bool = False,
    skip_traces: bool = False,
    skip_movies: bool = True,
):
    """
    Run WF pipeline for one dataset/session from a notebook,
    fully equivalent to the CLI flags.
    """

    # load base config
    with open(config_path, "r") as f:
        cfg = yaml.safe_load(f)

    # override dataset + session
    cfg["dataset_id"] = dataset_id
    cfg["session_id"] = session_id

    # write temporary config (pipeline expects a path)
    tmp_cfg_path = Path("_tmp_config.yaml")
    with tmp_cfg_path.open("w") as f:
        yaml.safe_dump(cfg, f)

    try:
        run_full_pipeline(
            config_path=tmp_cfg_path,
            run_motion=not skip_motion,
            run_mask=not skip_mask,
            run_dff=not skip_dff,
            run_roi=not skip_roi,
            run_traces=not skip_traces,
            run_movies=not skip_movies,
        )
    finally:
        tmp_cfg_path.unlink(missing_ok=True)

# %%
raw_root = "Z:/Individual_Folders/Tobi/WF_axonimaging/Functional_Imaging/data/raw"

processed_dir = "Z:/Individual_Folders/Tobi/WF_axonimaging/Functional_Imaging/data/processed"

# %%
from wf_analysis.utils import discover_animal_sessions

# %%
animal_sessions = discover_animal_sessions(
    base_dir=processed_dir,
    session_substring="leica",        # optional
    required_file_name="dff.npy",     # optional but recommended
)

# %%
animal_sessions
# Out:
# {'JPCM-08699': ['250905_leica', '250908_leica', '250911_leica'],
#  'JPCM-08704': ['250905_leica', '250908_leica', '250911_leica'],
#  'JPCM-08780': ['251017_leica', '251019_leica', '251020_leica'],
#  'JPCM-08781': ['251014_leica',
#   '251017_leica',
#   '251019_leica',
#   '251020_leica'],
#  'JPCM-08782': ['251014_leica',
#   '251017_leica',
#   '251019_leica',
#   '251020_leica'],
#  'JPCM-09177': ['260114_leica',
#   '260119_leica',
#   '260122_leica',
#   '260123_leica'],
#  'JPCM-09178': ['260115_leica',
#   '260119_leica',
#   '260122_leica',
#   '260123_leica'],
#  'JPCM-09185': ['260115_leica', '260119_leica', '260122_leica'],
#  'JPCM-09187': ['260122_leica', '260126_leica']}

# %%
CONFIG = "config_example.yaml"

for dataset_id, sessions in animal_sessions.items():
    for session_id in sessions:
        print(f"\n🚀 Running {dataset_id} / {session_id}")

        run_pipeline_for_dataset(
            config_path=CONFIG,
            dataset_id=dataset_id,
            session_id=session_id,
            skip_motion=True,
            skip_mask=True,
            skip_dff=False,
            skip_roi=False,
            skip_traces=False,
            skip_movies=True,
        )
# Out:
# 🚀 Running JPCM-08699 / 250905_leica
#
# === Stage 0: Motion correction (SKIPPED) ===
#
# === Stage 1: Mask application (SKIPPED) ===
#
# === Stage 2: DFF computation ===
#
# === DFF: repetition_sound (N=6) ===
#
# === Stage 3: ROI estimation ===
#
# --- Reading protocol: repetition_sound ---
# Reading 250905_115756 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08699/250905_leica/repetition_sound\250905_115756\data.h5)
# Reading 250905_115826 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08699/250905_leica/repetition_sound\250905_115826\data.h5)
# Reading 250905_115856 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08699/250905_leica/repetition_sound\250905_115856\data.h5)
# Reading 250905_115926 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08699/250905_leica/repetition_sound\250905_115926\data.h5)
# Reading 250905_115956 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08699/250905_leica/repetition_sound\250905_115956\data.h5)
# Reading 250905_120026 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08699/250905_leica/repetition_sound\250905_120026\data.h5)
# ✅ Done. Loaded 6 trials total.
# 0.0
# ✅ Saved ROI for protocol 'repetition_sound' at Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\processed\JPCM-08699\250905_leica\repetition_sound\ROI_stim_0.0.txt
#
# === Stage 3: Trace extraction ===
# ✅ Using ROI 'stim_0.0' for stimulus 0.0
#
# ✅ Pipeline finished successfully.
#
# 🚀 Running JPCM-08699 / 250908_leica
#
# === Stage 0: Motion correction (SKIPPED) ===
#
# === Stage 1: Mask application (SKIPPED) ===
#
# === Stage 2: DFF computation ===
#
# === DFF: repetition_sound (N=6) ===
#
# === Stage 3: ROI estimation ===
#
# --- Reading protocol: repetition_sound ---
# Reading 250908_105157 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08699/250908_leica/repetition_sound\250908_105157\data.h5)
# Reading 250908_105227 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08699/250908_leica/repetition_sound\250908_105227\data.h5)
# Reading 250908_105257 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08699/250908_leica/repetition_sound\250908_105257\data.h5)
# Reading 250908_105327 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08699/250908_leica/repetition_sound\250908_105327\data.h5)
# Reading 250908_105357 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08699/250908_leica/repetition_sound\250908_105357\data.h5)
# Reading 250908_105427 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08699/250908_leica/repetition_sound\250908_105427\data.h5)
# ✅ Done. Loaded 6 trials total.
# 0.0
# ✅ Saved ROI for protocol 'repetition_sound' at Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\processed\JPCM-08699\250908_leica\repetition_sound\ROI_stim_0.0.txt
#
# === Stage 3: Trace extraction ===
# ✅ Using ROI 'stim_0.0' for stimulus 0.0
#
# ✅ Pipeline finished successfully.
#
# 🚀 Running JPCM-08699 / 250911_leica
#
# === Stage 0: Motion correction (SKIPPED) ===
#
# === Stage 1: Mask application (SKIPPED) ===
#
# === Stage 2: DFF computation ===
#
# === DFF: repetition_sound (N=6) ===
#
# === Stage 3: ROI estimation ===
#
# --- Reading protocol: repetition_sound ---
# Reading 250911_103553 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08699/250911_leica/repetition_sound\250911_103553\data.h5)
# Reading 250911_103623 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08699/250911_leica/repetition_sound\250911_103623\data.h5)
# Reading 250911_103653 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08699/250911_leica/repetition_sound\250911_103653\data.h5)
# Reading 250911_103723 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08699/250911_leica/repetition_sound\250911_103723\data.h5)
# Reading 250911_103753 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08699/250911_leica/repetition_sound\250911_103753\data.h5)
# Reading 250911_103823 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08699/250911_leica/repetition_sound\250911_103823\data.h5)
# ✅ Done. Loaded 6 trials total.
# 0.0
# ✅ Saved ROI for protocol 'repetition_sound' at Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\processed\JPCM-08699\250911_leica\repetition_sound\ROI_stim_0.0.txt
#
# === Stage 3: Trace extraction ===
# ✅ Using ROI 'stim_0.0' for stimulus 0.0
#
# ✅ Pipeline finished successfully.
#
# 🚀 Running JPCM-08704 / 250905_leica
#
# === Stage 0: Motion correction (SKIPPED) ===
#
# === Stage 1: Mask application (SKIPPED) ===
#
# === Stage 2: DFF computation ===
#
# === DFF: repetition_sound (N=6) ===
#
# === Stage 3: ROI estimation ===
#
# --- Reading protocol: repetition_sound ---
# Reading 250905_131940 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08704/250905_leica/repetition_sound\250905_131940\data.h5)
# Reading 250905_132010 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08704/250905_leica/repetition_sound\250905_132010\data.h5)
# Reading 250905_132040 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08704/250905_leica/repetition_sound\250905_132040\data.h5)
# Reading 250905_132110 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08704/250905_leica/repetition_sound\250905_132110\data.h5)
# Reading 250905_132140 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08704/250905_leica/repetition_sound\250905_132140\data.h5)
# Reading 250905_132210 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08704/250905_leica/repetition_sound\250905_132210\data.h5)
# ✅ Done. Loaded 6 trials total.
# 0.0
# ✅ Saved ROI for protocol 'repetition_sound' at Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\processed\JPCM-08704\250905_leica\repetition_sound\ROI_stim_0.0.txt
#
# === Stage 3: Trace extraction ===
# ✅ Using ROI 'stim_0.0' for stimulus 0.0
#
# ✅ Pipeline finished successfully.
#
# 🚀 Running JPCM-08704 / 250908_leica
#
# === Stage 0: Motion correction (SKIPPED) ===
#
# === Stage 1: Mask application (SKIPPED) ===
#
# === Stage 2: DFF computation ===
#
# === DFF: repetition_sound (N=6) ===
#
# === Stage 3: ROI estimation ===
#
# --- Reading protocol: repetition_sound ---
# Reading 250908_114537 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08704/250908_leica/repetition_sound\250908_114537\data.h5)
# Reading 250908_114607 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08704/250908_leica/repetition_sound\250908_114607\data.h5)
# Reading 250908_114637 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08704/250908_leica/repetition_sound\250908_114637\data.h5)
# Reading 250908_114707 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08704/250908_leica/repetition_sound\250908_114707\data.h5)
# Reading 250908_114737 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08704/250908_leica/repetition_sound\250908_114737\data.h5)
# Reading 250908_114807 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08704/250908_leica/repetition_sound\250908_114807\data.h5)
# ✅ Done. Loaded 6 trials total.
# 0.0
# ✅ Saved ROI for protocol 'repetition_sound' at Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\processed\JPCM-08704\250908_leica\repetition_sound\ROI_stim_0.0.txt
#
# === Stage 3: Trace extraction ===
# ✅ Using ROI 'stim_0.0' for stimulus 0.0
#
# ✅ Pipeline finished successfully.
#
# 🚀 Running JPCM-08704 / 250911_leica
#
# === Stage 0: Motion correction (SKIPPED) ===
#
# === Stage 1: Mask application (SKIPPED) ===
#
# === Stage 2: DFF computation ===
#
# === DFF: repetition_sound (N=6) ===
#
# === Stage 3: ROI estimation ===
#
# --- Reading protocol: repetition_sound ---
# Reading 250911_113353 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08704/250911_leica/repetition_sound\250911_113353\data.h5)
# Reading 250911_113423 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08704/250911_leica/repetition_sound\250911_113423\data.h5)
# Reading 250911_113453 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08704/250911_leica/repetition_sound\250911_113453\data.h5)
# Reading 250911_113523 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08704/250911_leica/repetition_sound\250911_113523\data.h5)
# Reading 250911_113553 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08704/250911_leica/repetition_sound\250911_113553\data.h5)
# Reading 250911_113623 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08704/250911_leica/repetition_sound\250911_113623\data.h5)
# ✅ Done. Loaded 6 trials total.
# 0.0
# ✅ Saved ROI for protocol 'repetition_sound' at Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\processed\JPCM-08704\250911_leica\repetition_sound\ROI_stim_0.0.txt
#
# === Stage 3: Trace extraction ===
# ✅ Using ROI 'stim_0.0' for stimulus 0.0
#
# ✅ Pipeline finished successfully.
#
# 🚀 Running JPCM-08780 / 251017_leica
#
# === Stage 0: Motion correction (SKIPPED) ===
#
# === Stage 1: Mask application (SKIPPED) ===
#
# === Stage 2: DFF computation ===
#
# === DFF: repetition_sound (N=6) ===
#
# === Stage 3: ROI estimation ===
#
# --- Reading protocol: repetition_sound ---
# Reading 251017_131136 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08780/251017_leica/repetition_sound\251017_131136\data.h5)
# Reading 251017_131206 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08780/251017_leica/repetition_sound\251017_131206\data.h5)
# Reading 251017_131236 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08780/251017_leica/repetition_sound\251017_131236\data.h5)
# Reading 251017_131306 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08780/251017_leica/repetition_sound\251017_131306\data.h5)
# Reading 251017_131337 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08780/251017_leica/repetition_sound\251017_131337\data.h5)
# Reading 251017_131407 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08780/251017_leica/repetition_sound\251017_131407\data.h5)
# ✅ Done. Loaded 6 trials total.
# 0.0
# ✅ Saved ROI for protocol 'repetition_sound' at Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\processed\JPCM-08780\251017_leica\repetition_sound\ROI_stim_0.0.txt
#
# === Stage 3: Trace extraction ===
# ✅ Using ROI 'stim_0.0' for stimulus 0.0
#
# ✅ Pipeline finished successfully.
#
# 🚀 Running JPCM-08780 / 251019_leica
#
# === Stage 0: Motion correction (SKIPPED) ===
#
# === Stage 1: Mask application (SKIPPED) ===
#
# === Stage 2: DFF computation ===
#
# === DFF: repetition_sound (N=6) ===
#
# === Stage 3: ROI estimation ===
#
# --- Reading protocol: repetition_sound ---
# Reading 251019_151431 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08780/251019_leica/repetition_sound\251019_151431\data.h5)
# Reading 251019_151501 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08780/251019_leica/repetition_sound\251019_151501\data.h5)
# Reading 251019_151531 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08780/251019_leica/repetition_sound\251019_151531\data.h5)
# Reading 251019_151601 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08780/251019_leica/repetition_sound\251019_151601\data.h5)
# Reading 251019_151631 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08780/251019_leica/repetition_sound\251019_151631\data.h5)
# Reading 251019_151701 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08780/251019_leica/repetition_sound\251019_151701\data.h5)
# ✅ Done. Loaded 6 trials total.
# 0.0
# ✅ Saved ROI for protocol 'repetition_sound' at Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\processed\JPCM-08780\251019_leica\repetition_sound\ROI_stim_0.0.txt
#
# === Stage 3: Trace extraction ===
# ✅ Using ROI 'stim_0.0' for stimulus 0.0
#
# ✅ Pipeline finished successfully.
#
# 🚀 Running JPCM-08780 / 251020_leica
#
# === Stage 0: Motion correction (SKIPPED) ===
#
# === Stage 1: Mask application (SKIPPED) ===
#
# === Stage 2: DFF computation ===
#
# === DFF: repetition_sound (N=6) ===
#
# === Stage 3: ROI estimation ===
#
# --- Reading protocol: repetition_sound ---
# Reading 251020_161744 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08780/251020_leica/repetition_sound\251020_161744\data.h5)
# Reading 251020_161814 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08780/251020_leica/repetition_sound\251020_161814\data.h5)
# Reading 251020_161844 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08780/251020_leica/repetition_sound\251020_161844\data.h5)
# Reading 251020_161914 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08780/251020_leica/repetition_sound\251020_161914\data.h5)
# Reading 251020_161944 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08780/251020_leica/repetition_sound\251020_161944\data.h5)
# Reading 251020_162014 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08780/251020_leica/repetition_sound\251020_162014\data.h5)
# ✅ Done. Loaded 6 trials total.
# 0.0
# ✅ Saved ROI for protocol 'repetition_sound' at Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\processed\JPCM-08780\251020_leica\repetition_sound\ROI_stim_0.0.txt
#
# === Stage 3: Trace extraction ===
# ✅ Using ROI 'stim_0.0' for stimulus 0.0
#
# ✅ Pipeline finished successfully.
#
# 🚀 Running JPCM-08781 / 251014_leica
#
# === Stage 0: Motion correction (SKIPPED) ===
#
# === Stage 1: Mask application (SKIPPED) ===
#
# === Stage 2: DFF computation ===
#
# === DFF: repetition_sound (N=6) ===
#
# === Stage 3: ROI estimation ===
#
# --- Reading protocol: repetition_sound ---
# Reading 251014_104323 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08781/251014_leica/repetition_sound\251014_104323\data.h5)
# Reading 251014_104353 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08781/251014_leica/repetition_sound\251014_104353\data.h5)
# Reading 251014_104423 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08781/251014_leica/repetition_sound\251014_104423\data.h5)
# Reading 251014_104453 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08781/251014_leica/repetition_sound\251014_104453\data.h5)
# Reading 251014_104523 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08781/251014_leica/repetition_sound\251014_104523\data.h5)
# Reading 251014_104553 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08781/251014_leica/repetition_sound\251014_104553\data.h5)
# ✅ Done. Loaded 6 trials total.
# 0.0
# ✅ Saved ROI for protocol 'repetition_sound' at Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\processed\JPCM-08781\251014_leica\repetition_sound\ROI_stim_0.0.txt
#
# === Stage 3: Trace extraction ===
# ✅ Using ROI 'stim_0.0' for stimulus 0.0
#
# ✅ Pipeline finished successfully.
#
# 🚀 Running JPCM-08781 / 251017_leica
#
# === Stage 0: Motion correction (SKIPPED) ===
#
# === Stage 1: Mask application (SKIPPED) ===
#
# === Stage 2: DFF computation ===
#
# === DFF: repetition_sound (N=6) ===
#
# === Stage 3: ROI estimation ===
#
# --- Reading protocol: repetition_sound ---
# Reading 251017_141539 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08781/251017_leica/repetition_sound\251017_141539\data.h5)
# Reading 251017_141609 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08781/251017_leica/repetition_sound\251017_141609\data.h5)
# Reading 251017_141639 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08781/251017_leica/repetition_sound\251017_141639\data.h5)
# Reading 251017_141709 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08781/251017_leica/repetition_sound\251017_141709\data.h5)
# Reading 251017_141739 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08781/251017_leica/repetition_sound\251017_141739\data.h5)
# Reading 251017_141809 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08781/251017_leica/repetition_sound\251017_141809\data.h5)
# ✅ Done. Loaded 6 trials total.
# 0.0
# ✅ Saved ROI for protocol 'repetition_sound' at Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\processed\JPCM-08781\251017_leica\repetition_sound\ROI_stim_0.0.txt
#
# === Stage 3: Trace extraction ===
# ✅ Using ROI 'stim_0.0' for stimulus 0.0
#
# ✅ Pipeline finished successfully.
#
# 🚀 Running JPCM-08781 / 251019_leica
#
# === Stage 0: Motion correction (SKIPPED) ===
#
# === Stage 1: Mask application (SKIPPED) ===
#
# === Stage 2: DFF computation ===
#
# === DFF: repetition_sound (N=6) ===
#
# === Stage 3: ROI estimation ===
#
# --- Reading protocol: repetition_sound ---
# Reading 251019_162802 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08781/251019_leica/repetition_sound\251019_162802\data.h5)
# Reading 251019_162832 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08781/251019_leica/repetition_sound\251019_162832\data.h5)
# Reading 251019_162902 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08781/251019_leica/repetition_sound\251019_162902\data.h5)
# Reading 251019_162932 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08781/251019_leica/repetition_sound\251019_162932\data.h5)
# Reading 251019_163002 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08781/251019_leica/repetition_sound\251019_163002\data.h5)
# Reading 251019_163032 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08781/251019_leica/repetition_sound\251019_163032\data.h5)
# ✅ Done. Loaded 6 trials total.
# 0.0
# ✅ Saved ROI for protocol 'repetition_sound' at Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\processed\JPCM-08781\251019_leica\repetition_sound\ROI_stim_0.0.txt
#
# === Stage 3: Trace extraction ===
# ✅ Using ROI 'stim_0.0' for stimulus 0.0
#
# ✅ Pipeline finished successfully.
#
# 🚀 Running JPCM-08781 / 251020_leica
#
# === Stage 0: Motion correction (SKIPPED) ===
#
# === Stage 1: Mask application (SKIPPED) ===
#
# === Stage 2: DFF computation ===
#
# === DFF: repetition_sound (N=6) ===
#
# === Stage 3: ROI estimation ===
#
# --- Reading protocol: repetition_sound ---
# Reading 251020_101807 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08781/251020_leica/repetition_sound\251020_101807\data.h5)
# Reading 251020_101837 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08781/251020_leica/repetition_sound\251020_101837\data.h5)
# Reading 251020_101907 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08781/251020_leica/repetition_sound\251020_101907\data.h5)
# Reading 251020_101937 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08781/251020_leica/repetition_sound\251020_101937\data.h5)
# Reading 251020_102007 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08781/251020_leica/repetition_sound\251020_102007\data.h5)
# Reading 251020_102037 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08781/251020_leica/repetition_sound\251020_102037\data.h5)
# ✅ Done. Loaded 6 trials total.
# 0.0
# ✅ Saved ROI for protocol 'repetition_sound' at Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\processed\JPCM-08781\251020_leica\repetition_sound\ROI_stim_0.0.txt
#
# === Stage 3: Trace extraction ===
# ✅ Using ROI 'stim_0.0' for stimulus 0.0
#
# ✅ Pipeline finished successfully.
#
# 🚀 Running JPCM-08782 / 251014_leica
#
# === Stage 0: Motion correction (SKIPPED) ===
#
# === Stage 1: Mask application (SKIPPED) ===
#
# === Stage 2: DFF computation ===
#
# === DFF: repetition_sound (N=6) ===
#
# === Stage 3: ROI estimation ===
#
# --- Reading protocol: repetition_sound ---
# Reading 251014_130942 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08782/251014_leica/repetition_sound\251014_130942\data.h5)
# Reading 251014_131012 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08782/251014_leica/repetition_sound\251014_131012\data.h5)
# Reading 251014_131042 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08782/251014_leica/repetition_sound\251014_131042\data.h5)
# Reading 251014_131112 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08782/251014_leica/repetition_sound\251014_131112\data.h5)
# Reading 251014_131142 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08782/251014_leica/repetition_sound\251014_131142\data.h5)
# Reading 251014_131212 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08782/251014_leica/repetition_sound\251014_131212\data.h5)
# ✅ Done. Loaded 6 trials total.
# 0.0
# ✅ Saved ROI for protocol 'repetition_sound' at Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\processed\JPCM-08782\251014_leica\repetition_sound\ROI_stim_0.0.txt
#
# === Stage 3: Trace extraction ===
# ✅ Using ROI 'stim_0.0' for stimulus 0.0
#
# ✅ Pipeline finished successfully.
#
# 🚀 Running JPCM-08782 / 251017_leica
#
# === Stage 0: Motion correction (SKIPPED) ===
#
# === Stage 1: Mask application (SKIPPED) ===
#
# === Stage 2: DFF computation ===
#
# === DFF: repetition_sound (N=6) ===
#
# === Stage 3: ROI estimation ===
#
# --- Reading protocol: repetition_sound ---
# Reading 251017_154241 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08782/251017_leica/repetition_sound\251017_154241\data.h5)
# Reading 251017_154312 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08782/251017_leica/repetition_sound\251017_154312\data.h5)
# Reading 251017_154342 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08782/251017_leica/repetition_sound\251017_154342\data.h5)
# Reading 251017_154412 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08782/251017_leica/repetition_sound\251017_154412\data.h5)
# Reading 251017_154442 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08782/251017_leica/repetition_sound\251017_154442\data.h5)
# Reading 251017_154512 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08782/251017_leica/repetition_sound\251017_154512\data.h5)
# ✅ Done. Loaded 6 trials total.
# 0.0
# ✅ Saved ROI for protocol 'repetition_sound' at Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\processed\JPCM-08782\251017_leica\repetition_sound\ROI_stim_0.0.txt
#
# === Stage 3: Trace extraction ===
# ✅ Using ROI 'stim_0.0' for stimulus 0.0
#
# ✅ Pipeline finished successfully.
#
# 🚀 Running JPCM-08782 / 251019_leica
#
# === Stage 0: Motion correction (SKIPPED) ===
#
# === Stage 1: Mask application (SKIPPED) ===
#
# === Stage 2: DFF computation ===
#
# === DFF: repetition_sound (N=6) ===
#
# === Stage 3: ROI estimation ===
#
# --- Reading protocol: repetition_sound ---
# Reading 251019_173321 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08782/251019_leica/repetition_sound\251019_173321\data.h5)
# Reading 251019_173351 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08782/251019_leica/repetition_sound\251019_173351\data.h5)
# Reading 251019_173421 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08782/251019_leica/repetition_sound\251019_173421\data.h5)
# Reading 251019_173451 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08782/251019_leica/repetition_sound\251019_173451\data.h5)
# Reading 251019_173521 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08782/251019_leica/repetition_sound\251019_173521\data.h5)
# Reading 251019_173551 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08782/251019_leica/repetition_sound\251019_173551\data.h5)
# ✅ Done. Loaded 6 trials total.
# 0.0
# ✅ Saved ROI for protocol 'repetition_sound' at Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\processed\JPCM-08782\251019_leica\repetition_sound\ROI_stim_0.0.txt
#
# === Stage 3: Trace extraction ===
# ✅ Using ROI 'stim_0.0' for stimulus 0.0
#
# ✅ Pipeline finished successfully.
#
# 🚀 Running JPCM-08782 / 251020_leica
#
# === Stage 0: Motion correction (SKIPPED) ===
#
# === Stage 1: Mask application (SKIPPED) ===
#
# === Stage 2: DFF computation ===
#
# === DFF: repetition_sound (N=6) ===
#
# === Stage 3: ROI estimation ===
#
# --- Reading protocol: repetition_sound ---
# Reading 251020_172748 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08782/251020_leica/repetition_sound\251020_172748\data.h5)
# Reading 251020_172818 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08782/251020_leica/repetition_sound\251020_172818\data.h5)
# Reading 251020_172848 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08782/251020_leica/repetition_sound\251020_172848\data.h5)
# Reading 251020_172918 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08782/251020_leica/repetition_sound\251020_172918\data.h5)
# Reading 251020_172948 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08782/251020_leica/repetition_sound\251020_172948\data.h5)
# Reading 251020_173018 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-08782/251020_leica/repetition_sound\251020_173018\data.h5)
# ✅ Done. Loaded 6 trials total.
# 0.0
# ✅ Saved ROI for protocol 'repetition_sound' at Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\processed\JPCM-08782\251020_leica\repetition_sound\ROI_stim_0.0.txt
#
# === Stage 3: Trace extraction ===
# ✅ Using ROI 'stim_0.0' for stimulus 0.0
#
# ✅ Pipeline finished successfully.
#
# 🚀 Running JPCM-09177 / 260114_leica
#
# === Stage 0: Motion correction (SKIPPED) ===
#
# === Stage 1: Mask application (SKIPPED) ===
#
# === Stage 2: DFF computation ===
#
# === DFF: repetition_sound (N=6) ===
#
# === Stage 3: ROI estimation ===
#
# --- Reading protocol: repetition_sound ---
# Reading 260114_162418 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09177/260114_leica/repetition_sound\260114_162418\data.h5)
# Reading 260114_162448 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09177/260114_leica/repetition_sound\260114_162448\data.h5)
# Reading 260114_162518 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09177/260114_leica/repetition_sound\260114_162518\data.h5)
# Reading 260114_162548 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09177/260114_leica/repetition_sound\260114_162548\data.h5)
# Reading 260114_162618 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09177/260114_leica/repetition_sound\260114_162618\data.h5)
# Reading 260114_162649 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09177/260114_leica/repetition_sound\260114_162649\data.h5)
# ✅ Done. Loaded 6 trials total.
# 0.0
# ✅ Saved ROI for protocol 'repetition_sound' at Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\processed\JPCM-09177\260114_leica\repetition_sound\ROI_stim_0.0.txt
#
# === Stage 3: Trace extraction ===
# ✅ Using ROI 'stim_0.0' for stimulus 0.0
#
# ✅ Pipeline finished successfully.
#
# 🚀 Running JPCM-09177 / 260119_leica
#
# === Stage 0: Motion correction (SKIPPED) ===
#
# === Stage 1: Mask application (SKIPPED) ===
#
# === Stage 2: DFF computation ===
#
# === DFF: repetition_sound (N=6) ===
#
# === Stage 3: ROI estimation ===
#
# --- Reading protocol: repetition_sound ---
# Reading 260119_111643 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09177/260119_leica/repetition_sound\260119_111643\data.h5)
# Reading 260119_111713 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09177/260119_leica/repetition_sound\260119_111713\data.h5)
# Reading 260119_111743 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09177/260119_leica/repetition_sound\260119_111743\data.h5)
# Reading 260119_111813 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09177/260119_leica/repetition_sound\260119_111813\data.h5)
# Reading 260119_111843 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09177/260119_leica/repetition_sound\260119_111843\data.h5)
# Reading 260119_111913 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09177/260119_leica/repetition_sound\260119_111913\data.h5)
# ✅ Done. Loaded 6 trials total.
# 0.0
# ✅ Saved ROI for protocol 'repetition_sound' at Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\processed\JPCM-09177\260119_leica\repetition_sound\ROI_stim_0.0.txt
#
# === Stage 3: Trace extraction ===
# ✅ Using ROI 'stim_0.0' for stimulus 0.0
#
# ✅ Pipeline finished successfully.
#
# 🚀 Running JPCM-09177 / 260122_leica
#
# === Stage 0: Motion correction (SKIPPED) ===
#
# === Stage 1: Mask application (SKIPPED) ===
#
# === Stage 2: DFF computation ===
#
# === DFF: repetition_sound (N=6) ===
#
# === Stage 3: ROI estimation ===
#
# --- Reading protocol: repetition_sound ---
# Reading 260122_100906 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09177/260122_leica/repetition_sound\260122_100906\data.h5)
# Reading 260122_100936 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09177/260122_leica/repetition_sound\260122_100936\data.h5)
# Reading 260122_101006 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09177/260122_leica/repetition_sound\260122_101006\data.h5)
# Reading 260122_101036 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09177/260122_leica/repetition_sound\260122_101036\data.h5)
# Reading 260122_101106 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09177/260122_leica/repetition_sound\260122_101106\data.h5)
# Reading 260122_101136 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09177/260122_leica/repetition_sound\260122_101136\data.h5)
# ✅ Done. Loaded 6 trials total.
# 0.0
# ✅ Saved ROI for protocol 'repetition_sound' at Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\processed\JPCM-09177\260122_leica\repetition_sound\ROI_stim_0.0.txt
#
# === Stage 3: Trace extraction ===
# ✅ Using ROI 'stim_0.0' for stimulus 0.0
#
# ✅ Pipeline finished successfully.
#
# 🚀 Running JPCM-09177 / 260123_leica
#
# === Stage 0: Motion correction (SKIPPED) ===
#
# === Stage 1: Mask application (SKIPPED) ===
#
# === Stage 2: DFF computation ===
#
# === DFF: repetition_sound (N=6) ===
#
# === Stage 3: ROI estimation ===
#
# --- Reading protocol: repetition_sound ---
# Reading 260123_142325 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09177/260123_leica/repetition_sound\260123_142325\data.h5)
# Reading 260123_142355 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09177/260123_leica/repetition_sound\260123_142355\data.h5)
# Reading 260123_142425 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09177/260123_leica/repetition_sound\260123_142425\data.h5)
# Reading 260123_142455 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09177/260123_leica/repetition_sound\260123_142455\data.h5)
# Reading 260123_142525 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09177/260123_leica/repetition_sound\260123_142525\data.h5)
# Reading 260123_142555 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09177/260123_leica/repetition_sound\260123_142555\data.h5)
# ✅ Done. Loaded 6 trials total.
# 0.0
# ✅ Saved ROI for protocol 'repetition_sound' at Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\processed\JPCM-09177\260123_leica\repetition_sound\ROI_stim_0.0.txt
#
# === Stage 3: Trace extraction ===
# ✅ Using ROI 'stim_0.0' for stimulus 0.0
#
# ✅ Pipeline finished successfully.
#
# 🚀 Running JPCM-09178 / 260115_leica
#
# === Stage 0: Motion correction (SKIPPED) ===
#
# === Stage 1: Mask application (SKIPPED) ===
#
# === Stage 2: DFF computation ===
#
# === DFF: repetition_sound (N=6) ===
#
# === Stage 3: ROI estimation ===
#
# --- Reading protocol: repetition_sound ---
# Reading 260115_114242 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09178/260115_leica/repetition_sound\260115_114242\data.h5)
# Reading 260115_114312 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09178/260115_leica/repetition_sound\260115_114312\data.h5)
# Reading 260115_114342 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09178/260115_leica/repetition_sound\260115_114342\data.h5)
# Reading 260115_114412 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09178/260115_leica/repetition_sound\260115_114412\data.h5)
# Reading 260115_114444 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09178/260115_leica/repetition_sound\260115_114444\data.h5)
# Reading 260115_114514 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09178/260115_leica/repetition_sound\260115_114514\data.h5)
# ✅ Done. Loaded 6 trials total.
# 0.0
# ✅ Saved ROI for protocol 'repetition_sound' at Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\processed\JPCM-09178\260115_leica\repetition_sound\ROI_stim_0.0.txt
#
# === Stage 3: Trace extraction ===
# ✅ Using ROI 'stim_0.0' for stimulus 0.0
#
# ✅ Pipeline finished successfully.
#
# 🚀 Running JPCM-09178 / 260119_leica
#
# === Stage 0: Motion correction (SKIPPED) ===
#
# === Stage 1: Mask application (SKIPPED) ===
#
# === Stage 2: DFF computation ===
#
# === DFF: repetition_sound (N=6) ===
#
# === Stage 3: ROI estimation ===
#
# --- Reading protocol: repetition_sound ---
# Reading 260119_133257 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09178/260119_leica/repetition_sound\260119_133257\data.h5)
# Reading 260119_133327 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09178/260119_leica/repetition_sound\260119_133327\data.h5)
# Reading 260119_133357 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09178/260119_leica/repetition_sound\260119_133357\data.h5)
# Reading 260119_133427 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09178/260119_leica/repetition_sound\260119_133427\data.h5)
# Reading 260119_133500 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09178/260119_leica/repetition_sound\260119_133500\data.h5)
# Reading 260119_133531 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09178/260119_leica/repetition_sound\260119_133531\data.h5)
# ✅ Done. Loaded 6 trials total.
# 0.0
# ✅ Saved ROI for protocol 'repetition_sound' at Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\processed\JPCM-09178\260119_leica\repetition_sound\ROI_stim_0.0.txt
#
# === Stage 3: Trace extraction ===
# ✅ Using ROI 'stim_0.0' for stimulus 0.0
#
# ✅ Pipeline finished successfully.
#
# 🚀 Running JPCM-09178 / 260122_leica
#
# === Stage 0: Motion correction (SKIPPED) ===
#
# === Stage 1: Mask application (SKIPPED) ===
#
# === Stage 2: DFF computation ===
#
# === DFF: repetition_sound (N=6) ===
#
# === Stage 3: ROI estimation ===
#
# --- Reading protocol: repetition_sound ---
# Reading 260122_130033 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09178/260122_leica/repetition_sound\260122_130033\data.h5)
# Reading 260122_130103 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09178/260122_leica/repetition_sound\260122_130103\data.h5)
# Reading 260122_130133 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09178/260122_leica/repetition_sound\260122_130133\data.h5)
# Reading 260122_130203 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09178/260122_leica/repetition_sound\260122_130203\data.h5)
# Reading 260122_130233 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09178/260122_leica/repetition_sound\260122_130233\data.h5)
# Reading 260122_130303 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09178/260122_leica/repetition_sound\260122_130303\data.h5)
# ✅ Done. Loaded 6 trials total.
# 0.0
# ✅ Saved ROI for protocol 'repetition_sound' at Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\processed\JPCM-09178\260122_leica\repetition_sound\ROI_stim_0.0.txt
#
# === Stage 3: Trace extraction ===
# ✅ Using ROI 'stim_0.0' for stimulus 0.0
#
# ✅ Pipeline finished successfully.
#
# 🚀 Running JPCM-09178 / 260123_leica
#
# === Stage 0: Motion correction (SKIPPED) ===
#
# === Stage 1: Mask application (SKIPPED) ===
#
# === Stage 2: DFF computation ===
#
# === DFF: repetition_sound (N=6) ===
#
# === Stage 3: ROI estimation ===
#
# --- Reading protocol: repetition_sound ---
# Reading 260123_154952 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09178/260123_leica/repetition_sound\260123_154952\data.h5)
# Reading 260123_155022 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09178/260123_leica/repetition_sound\260123_155022\data.h5)
# Reading 260123_155052 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09178/260123_leica/repetition_sound\260123_155052\data.h5)
# Reading 260123_155122 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09178/260123_leica/repetition_sound\260123_155122\data.h5)
# Reading 260123_155152 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09178/260123_leica/repetition_sound\260123_155152\data.h5)
# Reading 260123_155222 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09178/260123_leica/repetition_sound\260123_155222\data.h5)
# ✅ Done. Loaded 6 trials total.
# 0.0
# ✅ Saved ROI for protocol 'repetition_sound' at Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\processed\JPCM-09178\260123_leica\repetition_sound\ROI_stim_0.0.txt
#
# === Stage 3: Trace extraction ===
# ✅ Using ROI 'stim_0.0' for stimulus 0.0
#
# ✅ Pipeline finished successfully.
#
# 🚀 Running JPCM-09185 / 260115_leica
#
# === Stage 0: Motion correction (SKIPPED) ===
#
# === Stage 1: Mask application (SKIPPED) ===
#
# === Stage 2: DFF computation ===
#
# === DFF: repetition_sound (N=6) ===
#
# === Stage 3: ROI estimation ===
#
# --- Reading protocol: repetition_sound ---
# Reading 260115_125655 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09185/260115_leica/repetition_sound\260115_125655\data.h5)
# Reading 260115_125725 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09185/260115_leica/repetition_sound\260115_125725\data.h5)
# Reading 260115_125755 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09185/260115_leica/repetition_sound\260115_125755\data.h5)
# Reading 260115_125825 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09185/260115_leica/repetition_sound\260115_125825\data.h5)
# Reading 260115_125855 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09185/260115_leica/repetition_sound\260115_125855\data.h5)
# Reading 260115_125925 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09185/260115_leica/repetition_sound\260115_125925\data.h5)
# ✅ Done. Loaded 6 trials total.
# 0.0
# ✅ Saved ROI for protocol 'repetition_sound' at Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\processed\JPCM-09185\260115_leica\repetition_sound\ROI_stim_0.0.txt
#
# === Stage 3: Trace extraction ===
# ✅ Using ROI 'stim_0.0' for stimulus 0.0
#
# ✅ Pipeline finished successfully.
#
# 🚀 Running JPCM-09185 / 260119_leica
#
# === Stage 0: Motion correction (SKIPPED) ===
#
# === Stage 1: Mask application (SKIPPED) ===
#
# === Stage 2: DFF computation ===
#
# === DFF: repetition_sound (N=6) ===
#
# === Stage 3: ROI estimation ===
#
# --- Reading protocol: repetition_sound ---
# Reading 260119_121608 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09185/260119_leica/repetition_sound\260119_121608\data.h5)
# Reading 260119_121639 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09185/260119_leica/repetition_sound\260119_121639\data.h5)
# Reading 260119_121709 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09185/260119_leica/repetition_sound\260119_121709\data.h5)
# Reading 260119_121742 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09185/260119_leica/repetition_sound\260119_121742\data.h5)
# Reading 260119_121812 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09185/260119_leica/repetition_sound\260119_121812\data.h5)
# Reading 260119_121842 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09185/260119_leica/repetition_sound\260119_121842\data.h5)
# ✅ Done. Loaded 6 trials total.
# 0.0
# ✅ Saved ROI for protocol 'repetition_sound' at Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\processed\JPCM-09185\260119_leica\repetition_sound\ROI_stim_0.0.txt
#
# === Stage 3: Trace extraction ===
# ✅ Using ROI 'stim_0.0' for stimulus 0.0
#
# ✅ Pipeline finished successfully.
#
# 🚀 Running JPCM-09185 / 260122_leica
#
# === Stage 0: Motion correction (SKIPPED) ===
#
# === Stage 1: Mask application (SKIPPED) ===
#
# === Stage 2: DFF computation ===
#
# === DFF: repetition_sound (N=12) ===
#
# === Stage 3: ROI estimation ===
#
# --- Reading protocol: repetition_sound ---
# Reading 260122_110351 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09185/260122_leica/repetition_sound\260122_110351\data.h5)
# Reading 260122_110421 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09185/260122_leica/repetition_sound\260122_110421\data.h5)
# Reading 260122_110451 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09185/260122_leica/repetition_sound\260122_110451\data.h5)
# Reading 260122_110521 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09185/260122_leica/repetition_sound\260122_110521\data.h5)
# Reading 260122_110551 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09185/260122_leica/repetition_sound\260122_110551\data.h5)
# Reading 260122_110621 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09185/260122_leica/repetition_sound\260122_110621\data.h5)
# Reading 260122_110641 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09185/260122_leica/repetition_sound\260122_110641\data.h5)
# Reading 260122_110711 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09185/260122_leica/repetition_sound\260122_110711\data.h5)
# Reading 260122_110741 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09185/260122_leica/repetition_sound\260122_110741\data.h5)
# Reading 260122_110811 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09185/260122_leica/repetition_sound\260122_110811\data.h5)
# Reading 260122_110841 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09185/260122_leica/repetition_sound\260122_110841\data.h5)
# Reading 260122_110911 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09185/260122_leica/repetition_sound\260122_110911\data.h5)
# ✅ Done. Loaded 12 trials total.
# 0.0
# ✅ Saved ROI for protocol 'repetition_sound' at Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\processed\JPCM-09185\260122_leica\repetition_sound\ROI_stim_0.0.txt
#
# === Stage 3: Trace extraction ===
# ✅ Using ROI 'stim_0.0' for stimulus 0.0
#
# ✅ Pipeline finished successfully.
#
# 🚀 Running JPCM-09187 / 260122_leica
#
# === Stage 0: Motion correction (SKIPPED) ===
#
# === Stage 1: Mask application (SKIPPED) ===
#
# === Stage 2: DFF computation ===
#
# === DFF: repetition_sound (N=6) ===
#
# === Stage 3: ROI estimation ===
#
# --- Reading protocol: repetition_sound ---
# Reading 260122_140401 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09187/260122_leica/repetition_sound\260122_140401\data.h5)
# Reading 260122_140431 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09187/260122_leica/repetition_sound\260122_140431\data.h5)
# Reading 260122_140501 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09187/260122_leica/repetition_sound\260122_140501\data.h5)
# Reading 260122_140531 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09187/260122_leica/repetition_sound\260122_140531\data.h5)
# Reading 260122_140601 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09187/260122_leica/repetition_sound\260122_140601\data.h5)
# Reading 260122_140631 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09187/260122_leica/repetition_sound\260122_140631\data.h5)
# ✅ Done. Loaded 6 trials total.
# 0.0
# ✅ Saved ROI for protocol 'repetition_sound' at Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\processed\JPCM-09187\260122_leica\repetition_sound\ROI_stim_0.0.txt
#
# === Stage 3: Trace extraction ===
# ✅ Using ROI 'stim_0.0' for stimulus 0.0
#
# ✅ Pipeline finished successfully.
#
# 🚀 Running JPCM-09187 / 260126_leica
#
# === Stage 0: Motion correction (SKIPPED) ===
#
# === Stage 1: Mask application (SKIPPED) ===
#
# === Stage 2: DFF computation ===
#
# === DFF: repetition_sound (N=6) ===
#
# === Stage 3: ROI estimation ===
#
# --- Reading protocol: repetition_sound ---
# Reading 260126_105445 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09187/260126_leica/repetition_sound\260126_105445\data.h5)
# Reading 260126_105516 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09187/260126_leica/repetition_sound\260126_105516\data.h5)
# Reading 260126_105546 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09187/260126_leica/repetition_sound\260126_105546\data.h5)
# Reading 260126_105616 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09187/260126_leica/repetition_sound\260126_105616\data.h5)
# Reading 260126_105646 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09187/260126_leica/repetition_sound\260126_105646\data.h5)
# Reading 260126_105716 (Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\raw/JPCM-09187/260126_leica/repetition_sound\260126_105716\data.h5)
# ✅ Done. Loaded 6 trials total.
# 0.0
# ✅ Saved ROI for protocol 'repetition_sound' at Z:\Individual_Folders\Tobi\WF_axonimaging\Functional_Imaging\data\processed\JPCM-09187\260126_leica\repetition_sound\ROI_stim_0.0.txt
#
# === Stage 3: Trace extraction ===
# ✅ Using ROI 'stim_0.0' for stimulus 0.0
#
# ✅ Pipeline finished successfully.
